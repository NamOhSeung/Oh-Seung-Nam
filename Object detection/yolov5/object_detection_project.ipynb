# %%
# Git clone
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5

# %%
# torch version 확인
import torch
import os
from IPython.display import Image, clear_output  # to display images
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.3.0+cu121 (CPU)

# %%
# 필수 라이브러리 설치
# !pip install -r /content/yolov5/requirements.txt

# %%
os.getcwd()
# Out:
# '/content/yolov5'

# %%
# 데이터 수집하고 압축했던 zip 파일 압축 해제
# !unzip uniform_detection.zip -d ./uniform_detection
# Out:
# Archive:  uniform_detection.zip
#    creating: ./uniform_detection/test/
#    creating: ./uniform_detection/test/images/
#   inflating: ./uniform_detection/test/images/football.mp4
#    creating: ./uniform_detection/train/
#   inflating: ./uniform_detection/train/classes.txt
#    creating: ./uniform_detection/train/images/
#   inflating: ./uniform_detection/train/images/1.JPG
#   inflating: ./uniform_detection/train/images/10.JPG
#   inflating: ./uniform_detection/train/images/100.JPG
#   inflating: ./uniform_detection/train/images/101.JPG
#   inflating: ./uniform_detection/train/images/103.JPG
#   inflating: ./uniform_detection/train/images/104.JPG
#   inflating: ./uniform_detection/train/images/105.JPG
#   inflating: ./uniform_detection/train/images/108.JPG
#   inflating: ./uniform_detection/train/images/109.JPG
#   inflating: ./uniform_detection/train/images/11.JPG
#   inflating: ./uniform_detection/train/images/110.JPG
#   inflating: ./uniform_detection/train/images/111.JPG
# ...

# %%
# !python train.py --data "data/uniform_data.yaml" --epoch 100
# Out:
# 2024-06-13 07:32:21.095768: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 07:32:21.095844: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 07:32:21.292627: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weight "/content/yolov5/runs/train/exp/weights/best.pt" --source "/content/yolov5/uniform_detection/test/images"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/yolov5/uniform_detection/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-321-g3742ab49 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/502) /content/yolov5/uniform_detection/test/images/football.mp4: 256x640 5 man utds, 3 man citys, 282.7ms
# video 1/1 (2/502) /content/yolov5/uniform_detection/test/images/football.mp4: 256x640 5 man utds, 3 man citys, 271.0ms
# ...
